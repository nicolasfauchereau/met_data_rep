# %%
# %matplotlib inline

# %%
# !date
# Out:
# Mon Jun  1 14:10:39 NZST 2015

# %%
import pyproj
import pandas as pd
import osr
from gdalconst import *
import numpy as np
from osgeo import gdal
from matplotlib import pyplot as plt

# %%
jj = pd.read_csv('/home/paul/Downloads/Data_test/rain_decile_1month.txt', names=['Data'])

# %%
filea='/home/paul/Downloads/Data_test/rain_decile_1month.txt'

# %% [raw]
# read in file
# take first 5 columns and strip the rest.

# %%
dataset = gdal.Open(filea, gdal.GA_ReadOnly)
dd = dataset.ReadAsArray()

# %%
print dataset.GetProjection()

# %%
gt = dataset.GetGeoTransform()

# %%
gt
# Out:
# (1980000.0, 500.0, 0.0, 6908000.0, 0.0, -500.0)

# %%
jj.head(10)
# Out:
#                                                 Data
# 0                                     NCOLS     2274
# 1                                     NROWS     3232
# 2                   XLLCORNER    1980000.0000000
# 3                   YLLCORNER    5292000.0000000
# 4                   CELLSIZE     500.00000000000
# 5                       NODATA_VALUE   -9999.000
# 6     -9999.0   -9999.0   -9999.0   -9999.0   -99...
# 7     -9999.0   -9999.0   -9999.0   -9999.0   -99...
# 8     -9999.0   -9999.0   -9999.0   -9999.0   -99...
# 9     -9999.0   -9999.0   -9999.0   -9999.0   -99...

# %%
cols = dataset.RasterXSize
print "cols = ",cols
rows = dataset.RasterYSize
print "rows = ",rows
# Out:
# cols =  2274
# rows =  3232

# %%
min_lon = gt[0]
min_lat = gt[3] + cols*gt[4] + rows*gt[5] 
max_lon = gt[0] + cols*gt[1] + rows*gt[2]
max_lat = gt[3] 
print("min lon: {}\nmax_lon: {}\nmin_lat: {}\nmax_lat: {}".format(min_lon, max_lon, min_lat, max_lat))
# Out:
# min lon: 1980000.0
# max_lon: 3117000.0
# min_lat: 5292000.0
# max_lat: 6908000.0

# %%
fig, ax = plt.subplots(figsize=(12,12))
plt.imshow ( dd, interpolation='nearest', vmin=0, cmap=plt.cm.gist_earth )

# %%
dd
# Out:
# array([[-9999., -9999., -9999., ..., -9999., -9999., -9999.],
#        [-9999., -9999., -9999., ..., -9999., -9999., -9999.],
#        [-9999., -9999., -9999., ..., -9999., -9999., -9999.],
#        ...,
#        [-9999., -9999., -9999., ..., -9999., -9999., -9999.],
#        [-9999., -9999., -9999., ..., -9999., -9999., -9999.],
#        [-9999., -9999., -9999., ..., -9999., -9999., -9999.]], dtype=float32)
